# %% [markdown]
# # Proboscidea Volcanium

# %%
import sys
if '..' not in sys.path:
    sys.path.insert(0, '..')

from day16 import *
import networkx as nx
import re
from itertools import product, permutations
from functools import reduce
# %matplotlib inline

import pandas as pd

from pyvis.network import Network

TEST_PATH = '../tests/16.txt'
INPUT_PATH = '../input/16.txt'

def nx_to_network(G, **kwargs):
    """To visualize a graph"""
    network = Network(notebook=True, cdn_resources='in_line', **kwargs)
    network.from_nx(G)
    return network

# %% [markdown]
# ## Part 1: Maximum pressure graph problem
#
# ### 1. Read input as a directed graph
#
# For example, suppose you have the following scan output:
#
# ```
# Valve AA has flow rate=0; tunnels lead to valves DD, II, BB
# Valve BB has flow rate=13; tunnels lead to valves CC, AA
# Valve CC has flow rate=2; tunnels lead to valves DD, BB
# Valve DD has flow rate=20; tunnels lead to valves CC, AA, EE
# Valve EE has flow rate=3; tunnels lead to valves FF, DD
# Valve FF has flow rate=0; tunnels lead to valves EE, GG
# Valve GG has flow rate=0; tunnels lead to valves FF, HH
# Valve HH has flow rate=22; tunnel leads to valve GG
# Valve II has flow rate=0; tunnels lead to valves AA, JJ
# Valve JJ has flow rate=21; tunnel leads to valve II
# ```
#
# We can model this as a graph $G$ with vertices (valves) $V$ and edges (tunnels) $E$.
# Each node $v$ has an attribute (flow rate) $f_v$.
# The edge weight (time to move between tunnels) is 1.

# %%
def read_input(fp):
    raw = open(fp).read()
    lines = raw.split('\n')

    G = nx.DiGraph()

    vertices = re.findall('Valve ([A-Z]{2}).*flow rate=(\d+)', raw)
    flows = [int(flow) for v, flow in vertices]
    valves = [v for v, flow in vertices]
    tunnels = []
    for v, l in zip(valves, lines):
        nodes = re.findall('[A-Z]{2}', l)[1:]
        tunnels.extend([(v, nodes[i]) for i in range(len(nodes))])

    G.add_nodes_from([(v, {"flow_rate": f, 
                           "label": f"{v}: {f}"}) for v, f in zip(valves, flows)])
    G.add_edges_from(tunnels, weight=1)
    return G


G = read_input(TEST_PATH)
network = nx_to_network(G, directed=True)
network.show("test_input.html")
# Out:
#         <iframe
#             width="100%"
#             height="600px"
#             src="test_input.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 2. Transform Graph
# We want to transform `G` to an easier graph structure, i.e. one where the time spent at a valve to open it is modeled.
# To do this, we need to add extra nodes $v' \in V': \forall v \in V: f_v > 0$.
#
# Functions used from networkx:
# - nx.add_nodes_from
# - nx.add_edges_from
# - nx.set_node_attributes

# %%
def update_valve_flow(G, valve, flow):
    G.nodes[valve]['flow_rate'] = flow
    G.nodes[valve]['label'] = f"{valve}: {flow}"

    
def transform(G, start=None):
    G_tf = G.copy()
    valves = filter(lambda valve: G.nodes[valve]['flow_rate'] > 0, G.nodes)
    for v in valves:
        f = G.nodes[v]['flow_rate']
        G_tf.add_node(f"{v}o", flow_rate=f, label=f"{v}o: {f}")
        for n in G.neighbors(v):
            G_tf.add_edge(f"{v}o", n, weight=1)
        G_tf.add_edge(v, f"{v}o", weight=1)
        update_valve_flow(G_tf, v, 0)
    if start is not None:
        G_tf.add_node("START", flow_rate=0, label="START")
        G_tf.add_edge("START", start)
    
    return G_tf

G_tf = transform(G, start='AA')
network = nx_to_network(G_tf, directed=True)
network.show("test_input_transformed.html")
# Out:
#         <iframe
#             width="100%"
#             height="600px"
#             src="test_input_transformed.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 3. Calculating the pressure over a path
#
# We're interested in 3 quantities when traversing through the tunnels on our transformed graph `G`:
# - suppose a path $P=(v_1, v_2, ..., v_T)$ leads from node $v_1$ to $v_T$. $v_1$ is from rest
# - the additional flow gained after traversing the path: $F(p) = \sum_{t=2}^{T} f_{v_t}$
# - the pressure released: $\rho(p) = \sum_{t=1}^{T}t f_{v_t}$
# - the time (in minutes) it took: $T$

# %%
path = ['AA', 'DD', 'DDo', 'CC', 'BB', 'BBo']

def calculate_pressure(G, p, memory=None):
    if memory is not None:
        key = (p[0], p[-1])
        if key in memory:
            return memory[key]
    flow_rates = np.array([G.nodes[valve]['flow_rate'] for valve in p])
    T = len(flow_rates) - 1
    # /!\ Don't include first state!
    P = np.sum(np.arange(T, 0, -1) * flow_rates[1:])
    F = flow_rates[1:].sum()
    if memory is not None:
        memory[key] = P, F, T
    return P, F, T

M = {}
calculate_pressure(G_tf, path, memory=M)
# G_tf.nodes
# Out:
# (93, 33, 5)

# %%
M
# Out:
# {('AA', 'BBo'): (93, 33, 5)}

# %% [markdown]
# ### 4. Distance matrix
# Store the shortest distance between all nodes with a flow rate as a matrix.
# This can be handy, since we will want to limit the breadth of our search space during our recursion to the K closest open valves of the node under investigation.
#
# **Important observations**
# - The shortest path from one open valve to the other NEVER passes by another open valve, so it coincides with the original graph `G`.
# - We must always move in between open valves to increase the flow, hence we filter our distance matrix on open valves only
# - It's always best to take the shortest path to open your next valve

# %%
# D = (pd.DataFrame(dict(nx.all_pairs_dijkstra_path_length(G_tf)))
# #      .filter(like='o', axis='rows')
# #      .filter(like='o', axis='columns')
#     )
# D
# doesn't yield the expected result for some reason...
from itertools import islice

def k_shortest_paths(G, source, target, k, weight=None):
    return list(
        islice(nx.shortest_simple_paths(G, source, target, weight=weight), k)
    )

def get_distance_matrix_and_simple_paths(G, k=3):
    open_valves = [v for v in G if v.endswith('o')]
    combos = filter(lambda t: t[0] != t[1], product(list(G), open_valves))

    all_simple_paths = {(s, d): k_shortest_paths(G, s, d, k=k)
                          for s, d in combos}
    all_min_distances = [(s, d, min([len(p) - 1 for p in path_list])) for (s, d), path_list in all_simple_paths.items()]

    D = pd.DataFrame(all_min_distances).set_index([0, 1]).unstack().fillna(0).astype(int)
    D.columns = D.columns.levels[1]
    
    SP = {(s, d): list(filter(lambda p: len(p) - 1 == D.loc[s, d], l)) for (s, d), l in all_simple_paths.items()}
    
    return D, SP

D, SP = get_distance_matrix_and_simple_paths(G_tf)
D
# Out:
# 1      BBo  CCo  DDo  EEo  HHo  JJo
# 0
# AA       2    3    2    3    6    3
# BB       1    2    3    4    7    4
# BBo      0    2    3    4    7    4
# CC       2    1    2    3    6    5
# CCo      2    0    2    3    6    5
# DD       3    2    1    2    5    4
# DDo      3    2    0    2    5    4
# EE       4    3    2    1    4    5
# EEo      4    3    2    0    4    5
# FF       5    4    3    2    3    6
# GG       6    5    4    3    2    7
# HH       7    6    5    4    1    8
# HHo      7    6    5    4    0    8
# II       3    4    3    4    7    2
# JJ       4    5    4    5    8    1
# JJo      4    5    4    5    8    0
# START    3    4    3    4    7    4

# %% [markdown]
# We also want to have the shortest paths for these ready for navigation! (without recalculating)

# %%
SP
# Out:
# {('AA', 'BBo'): [['AA', 'BB', 'BBo']],
#  ('AA', 'CCo'): [['AA', 'BB', 'CC', 'CCo'], ['AA', 'DD', 'CC', 'CCo']],
#  ('AA', 'DDo'): [['AA', 'DD', 'DDo']],
#  ('AA', 'EEo'): [['AA', 'DD', 'EE', 'EEo']],
#  ('AA', 'HHo'): [['AA', 'DD', 'EE', 'FF', 'GG', 'HH', 'HHo']],
#  ('AA', 'JJo'): [['AA', 'II', 'JJ', 'JJo']],
#  ('BB', 'BBo'): [['BB', 'BBo']],
#  ('BB', 'CCo'): [['BB', 'CC', 'CCo']],
#  ('BB', 'DDo'): [['BB', 'AA', 'DD', 'DDo'], ['BB', 'CC', 'DD', 'DDo']],
#  ('BB', 'EEo'): [['BB', 'CC', 'DD', 'EE', 'EEo'],
#   ['BB', 'AA', 'DD', 'EE', 'EEo']],
#  ('BB', 'HHo'): [['BB', 'AA', 'DD', 'EE', 'FF', 'GG', 'HH', 'HHo'],
#   ['BB', 'CC', 'DD', 'EE', 'FF', 'GG', 'HH', 'HHo']],
#  ('BB', 'JJo'): [['BB', 'AA', 'II', 'JJ', 'JJo']],
#  ('CC', 'BBo'): [['CC', 'BB', 'BBo']],
#  ('CC', 'CCo'): [['CC', 'CCo']],
#  ('CC', 'DDo'): [['CC', 'DD', 'DDo']],
#  ('CC', 'EEo'): [['CC', 'DD', 'EE', 'EEo']],
#  ('CC', 'HHo'): [['CC', 'DD', 'EE', 'FF', 'GG', 'HH', 'HHo']],
#  ('CC', 'JJo'): [['CC', 'BB', 'AA', 'II', 'JJ', 'JJo'],
#   ['CC', 'DD', 'AA', 'II', 'JJ', 'JJo']],
#  ('DD', 'BBo'): [['DD', 'AA', 'BB', 'BBo'], ['DD', 'CC', 'BB', 'BBo']],
#  ('DD', 'CCo'): [['DD', 'CC', 'CCo']],
#  ('DD', 'DDo'): [['DD', 'DDo']],
#  ('DD', 'EEo'): [['DD', 'EE', 'EEo']],
#  ('DD', 'HHo'): [['DD', 'EE', 'FF', 'GG', 'HH', 'HHo']],
#  ('DD', 'JJo'): [['DD', 'AA', 'II', 'JJ', 'JJo']],
#  ('EE', 'BBo'): [['EE', 'DD', 'CC', 'BB', 'BBo'],
#   ['EE', 'DD', 'AA', 'BB', 'BBo']],
#  ('EE', 'CCo'): [['EE', 'DD', 'CC', 'CCo']],
#  ('EE', 'DDo'): [['EE', 'DD', 'DDo']],
#  ('EE', 'EEo'): [['EE', 'EEo']],
#  ('EE', 'HHo'): [['EE', 'FF', 'GG', 'HH', 'HHo']],
#  ('EE', 'JJo'): [['EE', 'DD', 'AA', 'II', 'JJ', 'JJo']],
#  ('FF', 'BBo'): [['FF', 'EE', 'DD', 'CC', 'BB', 'BBo'],
#   ['FF', 'EE', 'DD', 'AA', 'BB', 'BBo']],
#  ('FF', 'CCo'): [['FF', 'EE', 'DD', 'CC', 'CCo']],
#  ('FF', 'DDo'): [['FF', 'EE', 'DD', 'DDo']],
#  ('FF', 'EEo'): [['FF', 'EE', 'EEo']],
#  ('FF', 'HHo'): [['FF', 'GG', 'HH', 'HHo']],
#  ('FF', 'JJo'): [['FF', 'EE', 'DD', 'AA', 'II', 'JJ', 'JJo']],
#  ('GG', 'BBo'): [['GG', 'FF', 'EE', 'DD', 'CC', 'BB', 'BBo'],
#   ['GG', 'FF', 'EE', 'DD', 'AA', 'BB', 'BBo']],
#  ('GG', 'CCo'): [['GG', 'FF', 'EE', 'DD', 'CC', 'CCo']],
#  ('GG', 'DDo'): [['GG', 'FF', 'EE', 'DD', 'DDo']],
#  ('GG', 'EEo'): [['GG', 'FF', 'EE', 'EEo']],
#  ('GG', 'HHo'): [['GG', 'HH', 'HHo']],
#  ('GG', 'JJo'): [['GG', 'FF', 'EE', 'DD', 'AA', 'II', 'JJ', 'JJo']],
#  ('HH', 'BBo'): [['HH', 'GG', 'FF', 'EE', 'DD', 'CC', 'BB', 'BBo'],
#   ['HH', 'GG', 'FF', 'EE', 'DD', 'AA', 'BB', 'BBo']],
#  ('HH', 'CCo'): [['HH', 'GG', 'FF', 'EE', 'DD', 'CC', 'CCo']],
#  ('HH', 'DDo'): [['HH', 'GG', 'FF', 'EE', 'DD', 'DDo']],
#  ('HH', 'EEo'): [['HH', 'GG', 'FF', 'EE', 'EEo']],
#  ('HH', 'HHo'): [['HH', 'HHo']],
#  ('HH', 'JJo'): [['HH', 'GG', 'FF', 'EE', 'DD', 'AA', 'II', 'JJ', 'JJo']],
#  ('II', 'BBo'): [['II', 'AA', 'BB', 'BBo']],
#  ('II', 'CCo'): [['II', 'AA', 'DD', 'CC', 'CCo'],
#   ['II', 'AA', 'BB', 'CC', 'CCo']],
#  ('II', 'DDo'): [['II', 'AA', 'DD', 'DDo']],
#  ('II', 'EEo'): [['II', 'AA', 'DD', 'EE', 'EEo']],
#  ('II', 'HHo'): [['II', 'AA', 'DD', 'EE', 'FF', 'GG', 'HH', 'HHo']],
#  ('II', 'JJo'): [['II', 'JJ', 'JJo']],
#  ('JJ', 'BBo'): [['JJ', 'II', 'AA', 'BB', 'BBo']],
#  ('JJ', 'CCo'): [['JJ', 'II', 'AA', 'DD', 'CC', 'CCo'],
#   ['JJ', 'II', 'AA', 'BB', 'CC', 'CCo']],
#  ('JJ', 'DDo'): [['JJ', 'II', 'AA', 'DD', 'DDo']],
#  ('JJ', 'EEo'): [['JJ', 'II', 'AA', 'DD', 'EE', 'EEo']],
#  ('JJ', 'HHo'): [['JJ', 'II', 'AA', 'DD', 'EE', 'FF', 'GG', 'HH', 'HHo']],
#  ('JJ', 'JJo'): [['JJ', 'JJo']],
#  ('BBo', 'CCo'): [['BBo', 'CC', 'CCo']],
#  ('BBo', 'DDo'): [['BBo', 'AA', 'DD', 'DDo'], ['BBo', 'CC', 'DD', 'DDo']],
#  ('BBo', 'EEo'): [['BBo', 'CC', 'DD', 'EE', 'EEo'],
#   ['BBo', 'AA', 'DD', 'EE', 'EEo']],
#  ('BBo', 'HHo'): [['BBo', 'CC', 'DD', 'EE', 'FF', 'GG', 'HH', 'HHo'],
#   ['BBo', 'AA', 'DD', 'EE', 'FF', 'GG', 'HH', 'HHo']],
#  ('BBo', 'JJo'): [['BBo', 'AA', 'II', 'JJ', 'JJo']],
#  ('CCo', 'BBo'): [['CCo', 'BB', 'BBo']],
#  ('CCo', 'DDo'): [['CCo', 'DD', 'DDo']],
#  ('CCo', 'EEo'): [['CCo', 'DD', 'EE', 'EEo']],
#  ('CCo', 'HHo'): [['CCo', 'DD', 'EE', 'FF', 'GG', 'HH', 'HHo']],
#  ('CCo', 'JJo'): [['CCo', 'BB', 'AA', 'II', 'JJ', 'JJo'],
#   ['CCo', 'DD', 'AA', 'II', 'JJ', 'JJo']],
#  ('DDo', 'BBo'): [['DDo', 'AA', 'BB', 'BBo'], ['DDo', 'CC', 'BB', 'BBo']],
#  ('DDo', 'CCo'): [['DDo', 'CC', 'CCo']],
#  ('DDo', 'EEo'): [['DDo', 'EE', 'EEo']],
#  ('DDo', 'HHo'): [['DDo', 'EE', 'FF', 'GG', 'HH', 'HHo']],
#  ('DDo', 'JJo'): [['DDo', 'AA', 'II', 'JJ', 'JJo']],
#  ('EEo', 'BBo'): [['EEo', 'DD', 'CC', 'BB', 'BBo'],
#   ['EEo', 'DD', 'AA', 'BB', 'BBo']],
#  ('EEo', 'CCo'): [['EEo', 'DD', 'CC', 'CCo']],
#  ('EEo', 'DDo'): [['EEo', 'DD', 'DDo']],
#  ('EEo', 'HHo'): [['EEo', 'FF', 'GG', 'HH', 'HHo']],
#  ('EEo', 'JJo'): [['EEo', 'DD', 'AA', 'II', 'JJ', 'JJo']],
#  ('HHo', 'BBo'): [['HHo', 'GG', 'FF', 'EE', 'DD', 'CC', 'BB', 'BBo'],
#   ['HHo', 'GG', 'FF', 'EE', 'DD', 'AA', 'BB', 'BBo']],
#  ('HHo', 'CCo'): [['HHo', 'GG', 'FF', 'EE', 'DD', 'CC', 'CCo']],
#  ('HHo', 'DDo'): [['HHo', 'GG', 'FF', 'EE', 'DD', 'DDo']],
#  ('HHo', 'EEo'): [['HHo', 'GG', 'FF', 'EE', 'EEo']],
#  ('HHo', 'JJo'): [['HHo', 'GG', 'FF', 'EE', 'DD', 'AA', 'II', 'JJ', 'JJo']],
#  ('JJo', 'BBo'): [['JJo', 'II', 'AA', 'BB', 'BBo']],
#  ('JJo', 'CCo'): [['JJo', 'II', 'AA', 'DD', 'CC', 'CCo'],
#   ['JJo', 'II', 'AA', 'BB', 'CC', 'CCo']],
#  ('JJo', 'DDo'): [['JJo', 'II', 'AA', 'DD', 'DDo']],
#  ('JJo', 'EEo'): [['JJo', 'II', 'AA', 'DD', 'EE', 'EEo']],
#  ('JJo', 'HHo'): [['JJo', 'II', 'AA', 'DD', 'EE', 'FF', 'GG', 'HH', 'HHo']],
#  ('START', 'BBo'): [['START', 'AA', 'BB', 'BBo']],
#  ('START', 'CCo'): [['START', 'AA', 'BB', 'CC', 'CCo'],
#   ['START', 'AA', 'DD', 'CC', 'CCo']],
#  ('START', 'DDo'): [['START', 'AA', 'DD', 'DDo']],
#  ('START', 'EEo'): [['START', 'AA', 'DD', 'EE', 'EEo']],
#  ('START', 'HHo'): [['START', 'AA', 'DD', 'EE', 'FF', 'GG', 'HH', 'HHo']],
#  ('START', 'JJo'): [['START', 'AA', 'II', 'JJ', 'JJo']]}

# %% [markdown]
# ### 5. Traversing path
# Whenever we have chosen a path with opening a valve, we need to remove the vertices we've created (since the valve cannot be opened again to increase the flow). This is equivalent to removing the source node (first node in the path).

# %%
def traverse_graph(G, path):
    # take a copy, since we will want to keep the original
    if not path[0].endswith('o'):
        return G
    G_update = G.copy()
    G_update.remove_node(path[0])
    return G_update

# %% [markdown]
# ### 6. Finding closest open valves
# Find the top $K$ closest valves that are open.

# %%
def find_K_closest_open_valves(G, D, source, K=3, exclude=[], max_distance=None):
    remaining = [v for v in G if v.endswith('o') and v != source and v not in exclude]
    top_valves = D.loc[source, remaining].sort_values()
    if max_distance is not None:
        top_valves = top_valves[top_valves <= max_distance]
    topK_valves = top_valves.head(K)
    return topK_valves.index.tolist()

source = 'START'
K = 10
destinations = find_K_closest_open_valves(G_tf, D, source, K, max_distance=3)
destinations
# Out:
# ['BBo', 'DDo']

# %% [markdown]
# Now we also want to know which paths are involved of course!!

# %%
def get_shortest_simple_paths(SP, source, destinations):
    return reduce(lambda x, y: x + y, [SP[(source, d)] for d in destinations])


get_shortest_simple_paths(SP, source, destinations)
# Out:
# [['START', 'AA', 'BB', 'BBo'], ['START', 'AA', 'DD', 'DDo']]

# %% [markdown]
# ### 7. Recursively finding the optimal trajectory

# %%
def find_max_pressure_trajectory(G, D, SP, source, visited=[], time=30, path=[], flow=0, 
                                 pressure=0, K=6, depth=20, memory=None):        
    if len(path) == 0:
        path = [source]
    
    if time <= 0 or depth <= 0:
        return path, pressure, flow
    
    
    visited = visited + [source]
    destinations = find_K_closest_open_valves(G, D, source, exclude=visited, K=K, max_distance=time)
    if len(destinations) == 0:
        return path, pressure + time * flow, flow
    
    best = path, pressure, flow 

    possible_paths = get_shortest_simple_paths(SP, source, destinations)
    for possible_path in possible_paths:
        extra_pressure, extra_flow, extra_time = calculate_pressure(G, possible_path, memory)
        
        p = pressure + extra_time * flow + extra_pressure
        f = flow + extra_flow
        t = time - extra_time
        new_path = path + possible_path[1:]
        new_source = possible_path[-1]

        final_path, final_pressure, final_flow = \
            find_max_pressure_trajectory(G, D, SP, new_source, visited, t, new_path, f, p, K, depth-1, memory)
        
        if final_pressure > best[1]:
            best = final_path, final_pressure, final_flow
    
    return best

# %%
M = {}
find_max_pressure_trajectory(G_tf, D, SP, 'START', time=30, K=3, depth=10, path=[], memory=M)
# get_shortest_simple_paths(G_tf, 'AA', ['BBo', 'DDo', 'CCo', 'EEo', 'JJo'])
# Out:
# (['START',
#   'AA',
#   'DD',
#   'DDo',
#   'AA',
#   'BB',
#   'BBo',
#   'AA',
#   'II',
#   'JJ',
#   'JJo',
#   'II',
#   'AA',
#   'DD',
#   'EE',
#   'FF',
#   'GG',
#   'HH',
#   'HHo',
#   'GG',
#   'FF',
#   'EE',
#   'EEo',
#   'DD',
#   'CC',
#   'CCo'],
#  1651,
#  81)

# %% [markdown]
# ### 8. Solution for the input

# %%
G = read_input(INPUT_PATH)
network = nx_to_network(G, directed=True)
network.show("test_input.html")
# Out:
#         <iframe
#             width="100%"
#             height="600px"
#             src="test_input.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
G_tf = transform(G, start='AA')
D, SP = get_distance_matrix_and_simple_paths(G_tf)

# wihtout cache
# %time find_max_pressure_trajectory(G_tf, D, SP, 'START', time=30, K=5, depth=15, path=[])
# Out:
# CPU times: user 10 s, sys: 24.1 ms, total: 10.1 s
# Wall time: 10.1 s
# (['START',
#   'AA',
#   'RO',
#   'TC',
#   'KU',
#   'KUo',
#   'TF',
#   'FR',
#   'FRo',
#   'ZK',
#   'ER',
#   'QO',
#   'QOo',
#   'MF',
#   'GQ',
#   'VD',
#   'VDo',
#   'TR',
#   'AJ',
#   'AJo',
#   'QX',
#   'CG',
#   'CGo',
#   'FF',
#   'ZL',
#   'WI',
#   'WIo',
#   'ZJ',
#   'GJ',
#   'GJo'],
#  1792,
#  128)

# %%
# with cache
M = {}
# %time find_max_pressure_trajectory(G_tf, D, SP, 'START', time=30, K=5, depth=15, path=[], memory=M)
# Out:
# CPU times: user 9.73 s, sys: 31.3 ms, total: 9.76 s
# Wall time: 9.83 s
# (['START',
#   'AA',
#   'RO',
#   'TC',
#   'KU',
#   'KUo',
#   'TF',
#   'FR',
#   'FRo',
#   'ZK',
#   'ER',
#   'QO',
#   'QOo',
#   'MF',
#   'GQ',
#   'VD',
#   'VDo',
#   'TR',
#   'AJ',
#   'AJo',
#   'QX',
#   'CG',
#   'CGo',
#   'FF',
#   'ZL',
#   'WI',
#   'WIo',
#   'ZJ',
#   'GJ',
#   'GJo'],
#  1792,
#  128)

# %% [markdown]
# ## Part 2
#
# Two players at the same time...
#
# **Key observations:**
# - fully symmetrical, which path the elf or the elephant takes doesn't matter
# - only use 1 shortest path
# - try to optimise speed with a cache
# - instead of always removing the nodes, keep track with a list of nodes visited, since they dont have any impact anyway on the shortest distances.

# %%
def find_max_pressure_trajectory_2p(G, D, SP, source1='START', source2='START', visited=[],
                                    time1=26, time2=26, path1=['START'], path2=['START'],
                                    flow1=0, flow2=0, pressure1=0, pressure2=0, N=[], K=6, depth=20, 
                                    memory=memory):        
    if (time1 <= 0 and time2 <= 0) or depth <= 0:
        if depth <= 0:
            print(f'Ran out of depth: time1: {time1}, time2: {time2}')
        return path1, path2, pressure1 + pressure2, flow1 + flow2        
    
    visited = visited + list(set([source1, source2]))

    destinations1 = find_K_closest_open_valves(G, D, source1, exclude=visited, K=K, max_distance=time1)
    destinations2 = find_K_closest_open_valves(G, D, source2, exclude=visited, K=K, max_distance=time2)
    
    if len(destinations1) == 0 and len(destinations2) == 0:
        return path1, path2, pressure1 + pressure2 + time1 * flow1 + time2 * flow2, flow1 + flow2
    if len(destinations1) == 0:
        # Only the second player continues
        path2, pressure2, flow2 = find_max_pressure_trajectory(G, D, SP, source2, visited,
                                                               time=time2, path=path2, flow=flow2, pressure=pressure2, 
                                                               depth=depth-1, memory=memory)
        return path1, path2, pressure1 + time1 * flow1 + pressure2, flow1 + flow2
    if len(destinations2) == 0:
        # Only the first player continues
        path1, pressure1, flow1 = find_max_pressure_trajectory(G, D, SP, source1, visited,
                                                               time=time1, path=path1, flow=flow1, pressure=pressure1,
                                                               depth=depth-1, memory=memory)
        return path1, path2, pressure1 + pressure2 + time2 * flow2, flow1 + flow2
    
    
    best = path1, path2, pressure1 + pressure2, flow1 + flow2
    # doesn't make sense for both the elf and the elephant to go to the same destination
    # if they're at the same location, we also don't care which elf/eleph goes where
    # they should not be allowed to travel to each other's location as well!
    if source1 == source2:
        combos = permutations(destinations1, 2)
    else:
        combos = filter(lambda t: t[0] != t[1] and t[0] != source2 and t[1] != source1, 
                        product(destinations1, destinations2))

    for d1, d2 in combos:
        possible_path1 = SP[(source1, d1)][0]
        possible_path2 = SP[(source2, d2)][0]
        
        extra_pressure1, extra_flow1, extra_time1 = calculate_pressure(G, possible_path1, memory)
        extra_pressure2, extra_flow2, extra_time2 = calculate_pressure(G, possible_path2, memory)
        
        p1, p2 = pressure1 + extra_time1 * flow1 + extra_pressure1, pressure2 + extra_time2 * flow2 + extra_pressure2
        f1, f2 = flow1 + extra_flow1, flow2 + extra_flow2
        t1, t2 = time1 - extra_time1, time2 - extra_time2
        
        new_path1, new_path2 = path1 + possible_path1[1:], path2 + possible_path2[1:]
        new_source1, new_source2 = possible_path1[-1], possible_path2[-1]

        final_path1, final_path2, final_pressure, final_flow = \
            find_max_pressure_trajectory_2p(G, D, SP, new_source1, new_source2, 
                                             visited,
                                             t1, t2, new_path1, new_path2,
                                             f1, f2, p1, p2, K, depth-1, memory=memory)
        
        if final_pressure > best[2]:
            best = final_path1, final_path2, final_pressure, final_flow
    
    return best

# %% [markdown]
# ### Test case

# %%
G = read_input(TEST_PATH)
G_tf = transform(G, start='AA')
D, SP = get_distance_matrix_and_simple_paths(G_tf)

# %time find_max_pressure_trajectory_2p(G_tf, D, SP, time1=26, time2=26, K=5, depth=15)
# Out:
# CPU times: user 346 ms, sys: 1.97 ms, total: 347 ms
# Wall time: 349 ms
# (['START',
#   'AA',
#   'DD',
#   'DDo',
#   'EE',
#   'FF',
#   'GG',
#   'HH',
#   'HHo',
#   'GG',
#   'FF',
#   'EE',
#   'EEo'],
#  ['START', 'AA', 'II', 'JJ', 'JJo', 'II', 'AA', 'BB', 'BBo', 'CC', 'CCo'],
#  1707,
#  81)

# %% [markdown]
# ### Input case

# %%
G = read_input(INPUT_PATH)
G_tf = transform(G, start='AA')
D, SP = get_distance_matrix_and_simple_paths(G_tf)

memory = dict()
# %time p1, p2, p, f = find_max_pressure_trajectory_2p(G_tf, D, SP, time1=15, time2=15, K=3, depth=15, memory=memory)
p1, p2, p, f
# Out:
# CPU times: user 5.23 s, sys: 10.8 ms, total: 5.24 s
# Wall time: 5.24 s
# (['START',
#   'AA',
#   'VQ',
#   'PI',
#   'PIo',
#   'EU',
#   'GJ',
#   'GJo',
#   'YJ',
#   'EQ',
#   'RC',
#   'RCo',
#   'WR',
#   'TX',
#   'FV',
#   'FVo'],
#  ['START',
#   'AA',
#   'DZ',
#   'VO',
#   'VD',
#   'VDo',
#   'GQ',
#   'MF',
#   'QO',
#   'QOo',
#   'ER',
#   'ZK',
#   'FR',
#   'FRo'],
#  771,
#  129)

# %%
from itertools import pairwise

for v1, v2 in pairwise(p1):
    G_tf.edges[(v1, v2)]['color'] = 'red'
    
for v1, v2 in pairwise(p2):
    G_tf.edges[(v1, v2)]['color'] = 'green'
    
network = nx_to_network(G_tf, directed=True)
network.show('part2.html')
# Out:
#         <iframe
#             width="100%"
#             height="600px"
#             src="part2.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# It takes a long time to complete, apparently (by looking with `cProfile`) the code can still be optimised within `find_K_closest_open_valves` as the code spends most of it's time there.

# %%
# %time p1, p2, p, f = find_max_pressure_trajectory_2p(G_tf, D, SP, time1=26, time2=26, K=3, depth=15, memory=memory)
p1, p2, p, f
# Out:
# CPU times: user 1h 1min 57s, sys: 22.1 s, total: 1h 2min 20s
# Wall time: 1h 2min 35s
# (['START',
#   'AA',
#   'VQ',
#   'PI',
#   'PIo',
#   'EU',
#   'GJ',
#   'GJo',
#   'YJ',
#   'EQ',
#   'RC',
#   'RCo',
#   'WR',
#   'TX',
#   'FV',
#   'FVo',
#   'KV',
#   'OF',
#   'OFo'],
#  ['START',
#   'AA',
#   'DZ',
#   'VO',
#   'VD',
#   'VDo',
#   'GQ',
#   'MF',
#   'QO',
#   'QOo',
#   'ER',
#   'ZK',
#   'FR',
#   'FRo',
#   'TF',
#   'KU',
#   'KUo',
#   'YW',
#   'MK',
#   'AJ',
#   'AJo',
#   'QX',
#   'CG',
#   'CGo',
#   'SU',
#   'LM',
#   'LMo'],
#  2587,
#  182)

# %%
import cProfile
cProfile.run("find_max_pressure_trajectory_2p(G_tf, D, SP, time1=20, time2=20, K=3, depth=15, memory=memory)")
# Out:
#          908222597 function calls (898334195 primitive calls) in 263.461 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    524534    0.173    0.000    0.173    0.000 1926699158.py:3(calculate_pressure)
#  183253/1    1.350    0.000  263.460  263.460 2155837623.py:1(find_max_pressure_trajectory_2p)
#    205608    0.054    0.000    0.054    0.000 2155837623.py:35(<lambda>)
#     73402    0.054    0.000    0.140    0.000 3266533892.py:1(get_shortest_simple_paths)
#     75384    0.013    0.000    0.013    0.000 3266533892.py:2(<lambda>)
#     73402    0.047    0.000    0.047    0.000 3266533892.py:2(<listcomp>)
# 217040/59010    0.564    0.000   79.007    0.001 4156550391.py:1(find_max_pressure_trajectory)
#    477356    2.374    0.000  261.138    0.001 978636205.py:1(find_K_closest_open_valves)
#    477356    3.373    0.000    5.928    0.000 978636205.py:2(<listcomp>)
#    477356    0.207    0.000    0.745    0.000 <__array_function__ internals>:177(concatenate)
#   1909424    0.826    0.000    1.752    0.000 <__array_function__ internals>:177(copyto)
#    477356    0.212    0.000    0.995    0.000 <__array_function__ internals>:177(nonzero)
#    954712    0.414    0.000    0.530    0.000 <frozen importlib._bootstrap>:1053(_handle_fromlist)
#         1    0.000    0.000  263.460  263.460 <string>:1(<module>)
#    477356    0.281    0.000   36.605    0.000 _decorators.py:323(wrapper)
#    954712    0.181    0.000    0.181    0.000 _dtype.py:24(_kind_name)
#    954712    0.234    0.000    0.234    0.000 _dtype.py:330(_name_includes_bit_suffix)
#    954712    0.881    0.000    1.354    0.000 _dtype.py:344(_name_get)
#    477356    0.127    0.000    0.953    0.000 _methods.py:46(_sum)
#    477356    0.132    0.000    0.661    0.000 _methods.py:54(_any)
#    954712    0.774    0.000    0.851    0.000 _ufunc_config.py:131(geterr)
#    954712    1.001    0.000    2.205    0.000 _ufunc_config.py:32(seterr)
#    477356    0.148    0.000    0.148    0.000 _ufunc_config.py:425(__init__)
#    477356    0.232    0.000    1.475    0.000 _ufunc_config.py:429(__enter__)
#    477356    0.249    0.000    1.211    0.000 _ufunc_config.py:434(__exit__)
#    954712    0.276    0.000    0.347    0.000 _validators.py:226(validate_bool_kwarg)
#    477356    0.327    0.000    1.396    0.000 _validators.py:449(validate_ascending)
#    954712    0.188    0.000    0.377    0.000 abc.py:117(__instancecheck__)
#    477356    0.095    0.000    0.194    0.000 abc.py:121(__subclasscheck__)
#    477356    0.382    0.000    0.884    0.000 algorithms.py:1480(take)
#    477356    0.514    0.000    1.613    0.000 array_ops.py:136(_na_arithmetic_op)
#    477356    1.219    0.000    5.547    0.000 array_ops.py:231(comparison_op)
#    477356    0.249    0.000   30.893    0.000 arraylike.py:52(__le__)
#    477356    0.926    0.000    2.499    0.000 base.py:1169(take)
#    477356    0.077    0.000    0.077    0.000 base.py:1195(_maybe_disallow_fill)
#    477356    0.489    0.000    3.719    0.000 base.py:1269(copy)
#   2864136    0.279    0.000    0.279    0.000 base.py:1735(name)
#    477356    0.195    0.000    0.427    0.000 base.py:1742(name)
#    477356    0.985    0.000    1.949    0.000 base.py:1753(_validate_names)
#    954712    0.268    0.000    0.357    0.000 base.py:1821(_get_names)
#    477356    0.040    0.000    0.040    0.000 base.py:2018(nlevels)
#    954712    0.101    0.000    0.101    0.000 base.py:242(disallow_kwargs)
#   1909424    0.500    0.000    4.238    0.000 base.py:2422(is_boolean)
#    954712    0.386    0.000    3.739    0.000 base.py:2746(inferred_type)
#    477356    0.657    0.000    1.679    0.000 base.py:2753(_is_all_dates)
#   1432068    0.212    0.000    1.058    0.000 base.py:2784(_is_multi)
#   4773560    1.361    0.000    7.714    0.000 base.py:286(is_dtype)
#   3341492    0.238    0.000    0.238    0.000 base.py:324(ndim)
#    477356    0.295    0.000    0.531    0.000 base.py:3755(get_loc)
#    954712    2.923    0.000   54.924    0.000 base.py:3889(get_indexer)
#    954712    0.781    0.000    3.671    0.000 base.py:3976(_get_indexer)
#    954712    0.666    0.000    5.443    0.000 base.py:4021(_check_indexing_method)
#    477356    0.328    0.000    0.619    0.000 base.py:4206(_validate_positional_slice)
#    954712    4.219    0.000   22.165    0.000 base.py:431(__new__)
#    477356    1.091    0.000   44.365    0.000 base.py:4361(reindex)
#    477356    0.125    0.000    5.079    0.000 base.py:4480(_wrap_reindex_result)
#    477356    0.620    0.000    4.954    0.000 base.py:4484(_maybe_preserve_names)
#  10024476    0.895    0.000    0.895    0.000 base.py:5133(_values)
#    954712    0.530    0.000    1.357    0.000 base.py:5159(_get_engine_target)
#   1909424    2.861    0.000    8.037    0.000 base.py:5347(__getitem__)
#    477356    0.314    0.000    0.667    0.000 base.py:54(shape)
#   1909424    2.665    0.000    9.143    0.000 base.py:5507(equals)
#    954712    0.158    0.000    0.354    0.000 base.py:56(<genexpr>)
#    954712    0.172    0.000    0.172    0.000 base.py:575(_ensure_array)
#    954712    0.362    0.000    1.037    0.000 base.py:58(_validate_set_axis)
#    954712    0.817    0.000    4.313    0.000 base.py:589(_dtype_to_subclass)
#    477356    0.318    0.000   37.947    0.000 base.py:6075(get_indexer_for)
#    477356    1.348    0.000   90.199    0.000 base.py:6099(_get_indexer_strict)
#    477356    0.726    0.000    2.029    0.000 base.py:6130(_raise_if_missing)
#   2864136    0.437    0.000    0.437    0.000 base.py:6236(_index_as_unique)
#    954712    0.675    0.000    2.178    0.000 base.py:6248(_maybe_promote)
#    954712    0.807    0.000    8.978    0.000 base.py:6328(_should_compare)
#    954712    0.411    0.000    1.712    0.000 base.py:6346(_is_comparable_dtype)
#    477356    0.048    0.000    0.048    0.000 base.py:6612(_maybe_cast_indexer)
#    954712    0.227    0.000   19.346    0.000 base.py:6619(_maybe_cast_listlike_indexer)
#   1432068    0.255    0.000    0.291    0.000 base.py:6625(_validate_indexer)
#   3341492    2.303    0.000    3.358    0.000 base.py:691(_simple_new)
#    954712    2.738    0.000   35.060    0.000 base.py:709(_with_infer)
#    477356    0.222    0.000    0.342    0.000 base.py:721(tolist)
#    954712    0.120    0.000    0.120    0.000 base.py:729(_constructor)
#   3818848    1.268    0.000   37.148    0.000 base.py:7320(ensure_index)
#    477356    0.092    0.000    0.120    0.000 base.py:7379(ensure_has_len)
#   2386780    0.854    0.000    2.490    0.000 base.py:7415(maybe_extract_name)
#    954712    1.020    0.000    7.296    0.000 base.py:7439(_maybe_cast_data_without_dtype)
#    954712    0.257    0.000    2.220    0.000 base.py:7499(unpack_nested_dtype)
#    477356    0.285    0.000    0.799    0.000 base.py:822(_view)
#    477356    0.137    0.000    0.936    0.000 base.py:831(_rename)
#   1909424    0.547    0.000    0.669    0.000 base.py:840(is_)
#   3341492    0.480    0.000    0.480    0.000 base.py:871(_reset_identity)
#   6205628    0.968    0.000    1.285    0.000 base.py:926(__len__)
#   1909424    0.257    0.000    0.257    0.000 base.py:987(dtype)
#    477356    0.105    0.000    0.105    0.000 blocks.py:1903(is_view)
#    477356    0.258    0.000    2.263    0.000 blocks.py:200(fill_value)
#   1432068    0.956    0.000    1.747    0.000 blocks.py:2091(maybe_coerce_values)
#   1432068    0.934    0.000    1.244    0.000 blocks.py:2120(get_block_type)
#   1432068    1.490    0.000    6.005    0.000 blocks.py:2172(new_block)
#   1432068    0.881    0.000    1.435    0.000 blocks.py:2186(check_ndim)
#    477356    0.317    0.000    0.317    0.000 blocks.py:236(make_block_same_class)
#    954712    0.169    0.000    0.169    0.000 blocks.py:500(dtype)
#    477356    0.147    0.000    0.147    0.000 blocks.py:827(iget)
#    954712    0.389    0.000    0.389    0.000 blocks.py:836(_slice)
#    477356    0.623    0.000    6.609    0.000 blocks.py:861(take_nd)
#    954712    0.291    0.000    0.291    0.000 cast.py:1422(sanitize_to_nanoseconds)
#    477356    0.228    0.000    0.228    0.000 cast.py:527(maybe_promote)
#    477356    0.347    0.000    0.419    0.000 common.py:1048(is_numeric_v_string_like)
#   1432068    0.427    0.000    0.595    0.000 common.py:1154(needs_i8_conversion)
#    954712    0.547    0.000    1.301    0.000 common.py:1204(is_numeric_dtype)
#   1432068    0.746    0.000    1.933    0.000 common.py:1246(is_float_dtype)
#   1909424    1.289    0.000    3.221    0.000 common.py:1278(is_bool_dtype)
#   1432068    0.223    0.000    0.319    0.000 common.py:1420(is_1d_only_ea_dtype)
#   2864136    0.981    0.000    1.520    0.000 common.py:1433(is_extension_array_dtype)
#   6205628    0.723    0.000    0.723    0.000 common.py:146(classes)
#   6205628    0.868    0.000    1.261    0.000 common.py:148(<lambda>)
#   1909424    0.598    0.000    0.908    0.000 common.py:1487(is_ea_or_datetimelike_dtype)
#    477356    0.124    0.000    0.157    0.000 common.py:151(cast_scalar_indexer)
#   3341492    0.378    0.000    0.378    0.000 common.py:151(classes_and_not_datetimelike)
#   6682984    1.141    0.000    1.678    0.000 common.py:1556(get_dtype)
#   3341492    0.611    0.000    0.836    0.000 common.py:156(<lambda>)
#   9547120    3.373    0.000    6.990    0.000 common.py:1591(_is_dtype_type)
#   4773560    1.864    0.000    6.221    0.000 common.py:162(is_object_dtype)
#   6205628    1.783    0.000    6.533    0.000 common.py:1725(validate_all_hashable)
#  12411256    1.751    0.000    3.240    0.000 common.py:1744(<genexpr>)
#    477356    0.164    0.000    0.242    0.000 common.py:1751(pandas_dtype)
#    477356    0.174    0.000    0.461    0.000 common.py:192(all_none)
#    954712    0.125    0.000    0.125    0.000 common.py:196(<genexpr>)
#   1432068    1.400    0.000    3.470    0.000 common.py:235(asarray_tuplesafe)
#    477356    0.106    0.000    0.138    0.000 common.py:303(is_null_slice)
#   2386780    0.418    0.000    0.548    0.000 common.py:352(apply_if_callable)
#    954712    0.432    0.000    2.857    0.000 common.py:463(is_interval_dtype)
#   3818848    1.238    0.000    7.430    0.000 common.py:501(is_categorical_dtype)
#    477356    0.177    0.000    0.177    0.000 common.py:537(is_string_or_object_np_dtype)
#    954712    0.258    0.000    0.717    0.000 common.py:556(require_length_match)
#    477356    0.495    0.000   32.526    0.000 common.py:57(new_method)
#   2386780    1.208    0.000    2.629    0.000 common.py:585(is_dtype_equal)
#    477356    0.202    0.000    0.693    0.000 common.py:684(is_integer_dtype)
#    954712    0.387    0.000    1.009    0.000 common.py:736(is_signed_integer_dtype)
#    477356    0.178    0.000    0.635    0.000 common.py:77(get_op_result_name)
#    954712    0.421    0.000    1.102    0.000 common.py:790(is_unsigned_integer_dtype)
#   2386780    1.886    0.000    7.807    0.000 common.py:96(is_bool_indexer)
#   3818848    2.997    0.000    7.389    0.000 config.py:116(_get_single_key)
#   3818848    1.782    0.000   11.229    0.000 config.py:134(_get_option)
#   3818848    1.035    0.000   12.264    0.000 config.py:262(__call__)
#   3818848    0.622    0.000    0.622    0.000 config.py:579(_select_options)
#   3818848    1.548    0.000    2.058    0.000 config.py:597(_get_root)
#   7637696    1.792    0.000    1.792    0.000 config.py:611(_get_deprecated_option)
#   3818848    0.713    0.000    1.455    0.000 config.py:638(_translate_key)
#   3818848    0.880    0.000    1.931    0.000 config.py:650(_warn_if_deprecated)
#   1909424    0.495    0.000    2.886    0.000 construction.py:399(extract_array)
#   3341492    1.070    0.000    1.216    0.000 construction.py:461(ensure_wrapped_if_datetimelike)
#    954712    2.130    0.000    6.335    0.000 construction.py:493(sanitize_array)
#    954712    0.396    0.000    0.748    0.000 construction.py:676(_sanitize_ndim)
#    954712    0.239    0.000    0.306    0.000 construction.py:713(_sanitize_str_dtypes)
#    954712    0.241    0.000    0.287    0.000 construction.py:733(_maybe_repeat)
#    954712    0.717    0.000    1.127    0.000 construction.py:744(_try_cast)
#    954712    0.330    0.000    0.482    0.000 construction.py:861(is_empty_data)
#    477356    0.092    0.000    0.092    0.000 contextlib.py:420(__init__)
#    477356    0.045    0.000    0.045    0.000 contextlib.py:423(__enter__)
#    477356    0.056    0.000    0.056    0.000 contextlib.py:426(__exit__)
#    477356    0.110    0.000    0.505    0.000 dispatch.py:13(should_extension_dispatch)
#    954712    0.531    0.000    2.356    0.000 dtypes.py:1247(is_dtype)
#    954712    0.146    0.000    0.146    0.000 enum.py:801(value)
#    477356    0.183    0.000    0.813    0.000 expressions.py:225(evaluate)
#    477356    0.113    0.000    0.630    0.000 expressions.py:64(_evaluate_standard)
#   2864136    0.814    0.000    0.814    0.000 flags.py:49(__init__)
#   2864136    0.278    0.000    0.278    0.000 flags.py:53(allows_duplicate_labels)
#   2864136    0.716    0.000    0.716    0.000 flags.py:85(allows_duplicate_labels)
#    954712    0.268    0.000    0.268    0.000 frame.py:856(axes)
#    477356    0.053    0.000    0.053    0.000 fromnumeric.py:1862(_nonzero_dispatcher)
#    477356    0.150    0.000    0.589    0.000 fromnumeric.py:1866(nonzero)
#    477356    0.202    0.000    0.439    0.000 fromnumeric.py:51(_wrapfunc)
#    477356    0.283    0.000    0.345    0.000 frozen.py:70(__getitem__)
#   2864136    2.921    0.000    3.735    0.000 generic.py:259(__init__)
#   2864136    0.544    0.000    0.544    0.000 generic.py:332(attrs)
#   5728272    0.621    0.000    0.621    0.000 generic.py:353(flags)
#    477356    2.126    0.000   14.550    0.000 generic.py:3908(xs)
#  40575260    5.355    0.000    7.395    0.000 generic.py:40(_check)
#    477356    0.115    0.000    0.272    0.000 generic.py:4114(_set_is_copy)
#    477356    0.137    0.000    0.489    0.000 generic.py:4315(_is_view)
#  40575260    6.014    0.000   13.527    0.000 generic.py:45(_instancecheck)
#    477356    1.334    0.000   22.564    0.000 generic.py:5332(_reindex_with_indexers)
#    477356    0.382    0.000   12.959    0.000 generic.py:5474(head)
#   4773560    0.617    0.000    0.617    0.000 generic.py:550(_get_axis_number)
#    477356    0.147    0.000    0.191    0.000 generic.py:558(_get_axis_name)
#   2864136    1.116    0.000    1.490    0.000 generic.py:564(_get_axis)
#    477356    0.185    0.000    0.259    0.000 generic.py:570(_get_block_manager_axis)
#   2864136    5.420    0.000   11.878    0.000 generic.py:5844(__finalize__)
#   3818848    1.571    0.000    1.571    0.000 generic.py:5888(__getattr__)
#   4296204    2.924    0.000   11.000    0.000 generic.py:5904(__setattr__)
#    477356    0.399    0.000    1.222    0.000 generic.py:5959(_protect_consolidate)
#    477356    0.202    0.000    1.424    0.000 generic.py:5973(_consolidate_inplace)
#    477356    0.237    0.000    0.704    0.000 generic.py:5977(f)
#    954712    0.167    0.000    0.167    0.000 generic.py:664(ndim)
#    477356    0.133    0.000    0.172    0.000 graph.py:439(__iter__)
# 1432068/954712    1.910    0.000  157.789    0.000 indexing.py:1059(__getitem__)
#   1432068    0.251    0.000    0.317    0.000 indexing.py:1063(<genexpr>)
#   1432068    0.346    0.000    0.554    0.000 indexing.py:1064(<genexpr>)
#    954712    0.221    0.000    0.316    0.000 indexing.py:1108(_validate_key)
#    477356    0.948    0.000    1.478    0.000 indexing.py:1130(_is_scalar_access)
#    477356    0.616    0.000  114.412    0.000 indexing.py:1213(_getitem_iterable)
#    477356    0.967    0.000  140.608    0.000 indexing.py:1244(_getitem_tuple)
#    477356    0.230    0.000   14.780    0.000 indexing.py:1258(_get_label)
#    954712    1.810    0.000  134.560    0.000 indexing.py:1276(_getitem_axis)
#    477356    0.100    0.000    0.100    0.000 indexing.py:139(iloc)
#    477356    0.474    0.000   91.078    0.000 indexing.py:1406(_get_listlike_indexer)
#    477356    0.277    0.000   11.553    0.000 indexing.py:1592(_getitem_axis)
#    477356    0.563    0.000   10.979    0.000 indexing.py:1629(_get_slice_axis)
#    477356    0.530    0.000    8.280    0.000 indexing.py:2522(check_bool_indexer)
#    477356    0.190    0.000    0.401    0.000 indexing.py:2629(is_label_like)
#    477356    0.116    0.000    0.116    0.000 indexing.py:2643(need_slice)
#   1909424    0.964    0.000    2.304    0.000 indexing.py:2656(check_deprecated_indexers)
#   1432068    0.202    0.000    0.259    0.000 indexing.py:2661(<genexpr>)
#   1432068    0.176    0.000    0.224    0.000 indexing.py:2672(<genexpr>)
#    954712    0.165    0.000    0.165    0.000 indexing.py:278(loc)
#    477356    0.142    0.000    0.458    0.000 indexing.py:842(_expand_ellipsis)
#   1432068    0.147    0.000    0.147    0.000 indexing.py:848(<genexpr>)
#    477356    0.229    0.000    0.777    0.000 indexing.py:881(_is_nested_tuple_indexer)
#   1432068    0.203    0.000    0.272    0.000 indexing.py:888(<genexpr>)
#    477356    0.117    0.000    0.145    0.000 indexing.py:899(_validate_key_length)
#    477356    1.583    0.000  138.990    0.000 indexing.py:931(_getitem_lowerdim)
#   2386780    0.581    0.000    1.845    0.000 inference.py:188(is_array_like)
#   9069764    1.627    0.000    2.321    0.000 inference.py:325(is_hashable)
#    477356    0.797    0.000    4.938    0.000 managers.py:1080(fast_xs)
#    477356    0.143    0.000    0.143    0.000 managers.py:1843(is_consolidated)
#    954712    0.081    0.000    0.081    0.000 managers.py:1879(ndim)
#   2864136    1.519    0.000   11.443    0.000 managers.py:1888(__init__)
#    477356    0.456    0.000    2.750    0.000 managers.py:1914(from_blocks)
#    954712    0.700    0.000    8.618    0.000 managers.py:1931(from_array)
#   1909424    0.256    0.000    0.256    0.000 managers.py:2006(_block)
#    954712    2.239    0.000   10.914    0.000 managers.py:2020(getitem_mgr)
#    954712    0.112    0.000    0.112    0.000 managers.py:2051(index)
#   3341492    0.921    0.000    1.067    0.000 managers.py:2055(dtype)
#   1909424    0.754    0.000    0.893    0.000 managers.py:2066(internal_values)
#    954712    0.326    0.000    1.363    0.000 managers.py:228(set_axis)
#    477356    0.330    0.000    0.444    0.000 managers.py:2404(_preprocess_slice_or_indexer)
#   2864136    0.935    0.000    9.925    0.000 managers.py:2427(_using_copy_on_write)
#    477356    0.218    0.000    0.352    0.000 managers.py:515(is_view)
#    477356    0.141    0.000    0.284    0.000 managers.py:675(consolidate)
#    477356    0.881    0.000   15.438    0.000 managers.py:691(reindex_indexer)
#    477356    1.282    0.000   11.301    0.000 managers.py:776(_slice_take_blocks_ax0)
#    954712    0.138    0.000    0.138    0.000 missing.py:107(clean_fill_method)
#    954712    0.214    0.000    2.289    0.000 missing.py:108(isna)
#    477356    0.225    0.000    0.225    0.000 missing.py:140(dispatch_fill_zeros)
#    954712    0.560    0.000    2.075    0.000 missing.py:191(_isna)
#    477356    0.665    0.000    1.061    0.000 missing.py:268(_isna_array)
#   1432068    0.681    0.000    0.862    0.000 missing.py:460(array_equivalent)
#         6    0.000    0.000    0.000    0.000 missing.py:564(_array_equivalent_object)
#    477356    0.389    0.000    1.921    0.000 missing.py:641(na_value_for_dtype)
#    954712    0.239    0.000    0.377    0.000 missing.py:910(clean_reindex_fill_method)
#   1909424    0.203    0.000    0.203    0.000 multiarray.py:1071(copyto)
#    477356    0.063    0.000    0.063    0.000 multiarray.py:148(concatenate)
#   1909424    1.336    0.000    3.899    0.000 numeric.py:289(full)
#    954712    0.218    0.000    1.308    0.000 re.py:249(compile)
#    954712    0.586    0.000    1.090    0.000 re.py:288(_compile)
#    954712    1.049    0.000   20.993    0.000 series.py:1068(_get_values)
#    477356    0.676    0.000   19.059    0.000 series.py:3194(_construct_result)
#   2864136    5.013    0.000   43.790    0.000 series.py:342(__init__)
#    477356    1.793    0.000   36.293    0.000 series.py:3573(sort_values)
#   2386780    0.197    0.000    0.197    0.000 series.py:546(_constructor)
#    954712    0.702    0.000    3.961    0.000 series.py:565(_set_axis)
#   3341492    0.680    0.000    1.747    0.000 series.py:596(dtype)
#   6205628    2.008    0.000    3.178    0.000 series.py:611(name)
#    477356    1.326    0.000   30.644    0.000 series.py:6233(_cmp_method)
#   5728272    2.557    0.000    8.542    0.000 series.py:661(name)
#   1909424    0.512    0.000    1.405    0.000 series.py:708(_values)
#    477356    0.189    0.000    0.426    0.000 series.py:846(__array__)
#    477356    0.135    0.000    9.366    0.000 series.py:961(_slice)
#    477356    1.187    0.000   24.833    0.000 series.py:966(__getitem__)
#    477356    2.249    0.000    8.361    0.000 sorting.py:378(nargsort)
#    477356    1.027    0.000    4.466    0.000 take.py:120(_take_nd_ndarray)
#    477356    0.190    0.000    0.190    0.000 take.py:326(_get_take_nd_function)
#    477356    0.958    0.000    1.984    0.000 take.py:554(_take_preprocess_indexer_and_fill_value)
#    477356    0.533    0.000    5.091    0.000 take.py:57(take_nd)
#    954712    0.324    0.000    0.471    0.000 types.py:176(__get__)
#    477356    0.198    0.000    0.599    0.000 typing.py:1154(__subclasscheck__)
#   1909424    0.166    0.000    0.166    0.000 typing.py:1737(cast)
#    477356    0.175    0.000    0.773    0.000 typing.py:993(__instancecheck__)
#    477356    1.025    0.000    4.891    0.000 utils.py:430(check_array_indexer)
#   1432068    0.308    0.000    0.497    0.000 utils.py:66(is_list_like_indexer)
#    954712    1.508    0.000    4.279    0.000 warnings.py:130(filterwarnings)
#    954712    0.755    0.000    1.257    0.000 warnings.py:181(_add_filter)
#    954712    0.486    0.000    0.486    0.000 warnings.py:437(__init__)
#    954712    0.683    0.000    0.738    0.000 warnings.py:458(__enter__)
#    954712    0.505    0.000    0.556    0.000 warnings.py:477(__exit__)
#   3341492    0.399    0.000    0.399    0.000 {built-in method __new__ of type object at 0x102c630a0}
#    954712    0.189    0.000    0.189    0.000 {built-in method _abc._abc_instancecheck}
#    477356    0.099    0.000    0.099    0.000 {built-in method _abc._abc_subclasscheck}
#     73402    0.026    0.000    0.039    0.000 {built-in method _functools.reduce}
#    477356    0.517    0.000    0.517    0.000 {built-in method _operator.le}
#   2864136    0.152    0.000    0.152    0.000 {built-in method _warnings._filters_mutated}
#   6682984    1.672    0.000    5.037    0.000 {built-in method builtins.all}
#   1909424    0.718    0.000    1.620    0.000 {built-in method builtins.any}
#   2386780    0.131    0.000    0.131    0.000 {built-in method builtins.callable}
#         1    0.000    0.000  263.461  263.461 {built-in method builtins.exec}
#  53941228    3.170    0.000    3.486    0.000 {built-in method builtins.getattr}
#   7637696    0.766    0.000    1.270    0.000 {built-in method builtins.hasattr}
#   9069764    0.694    0.000    0.694    0.000 {built-in method builtins.hash}
# 168029312/165642532   15.508    0.000   29.987    0.000 {built-in method builtins.isinstance}
#  18139528    1.241    0.000    1.435    0.000 {built-in method builtins.issubclass}
#    477356    0.038    0.000    0.038    0.000 {built-in method builtins.iter}
# 37531245/31325617    2.954    0.000    3.922    0.000 {built-in method builtins.len}
#    477356    0.150    0.000    0.150    0.000 {built-in method builtins.sorted}
#    477356    0.591    0.000    0.591    0.000 {built-in method numpy.arange}
#    477356    0.041    0.000    0.041    0.000 {built-in method numpy.asanyarray}
# 10024476/9547120    2.688    0.000    3.467    0.000 {built-in method numpy.asarray}
#   2864136    1.340    0.000    1.929    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#   2386780    0.516    0.000    0.516    0.000 {built-in method numpy.empty}
#   1909424    0.189    0.000    0.189    0.000 {built-in method numpy.geterrobj}
#    954712    0.241    0.000    0.241    0.000 {built-in method numpy.seterrobj}
#    477356    0.304    0.000    0.304    0.000 {built-in method pandas._libs.lib.is_datetime_array}
#    477356    0.107    0.000    0.107    0.000 {built-in method pandas._libs.missing.checknull}
#    477356    0.027    0.000    0.027    0.000 {function FrozenList.__getitem__ at 0x1280c2560}
#    477356    0.137    0.000    0.798    0.000 {method 'any' of 'numpy.ndarray' objects}
#    477356    0.362    0.000    0.362    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#  37233768    2.555    0.000    2.555    0.000 {method 'endswith' of 'str' objects}
#    954712    1.454    0.000    1.454    0.000 {method 'get_indexer' of 'pandas._libs.index.IndexEngine' objects}
#    477356    0.187    0.000    0.187    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#    954712    0.090    0.000    0.090    0.000 {method 'insert' of 'list' objects}
#    477356    0.034    0.000    0.034    0.000 {method 'keys' of 'dict' objects}
#    477356    0.161    0.000    0.161    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#        24    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#    954712    1.354    0.000    1.354    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#    954712    0.367    0.000    0.367    0.000 {method 'remove' of 'list' objects}
#   3818848    0.510    0.000    0.510    0.000 {method 'split' of 'str' objects}
#    477356    0.139    0.000    1.092    0.000 {method 'sum' of 'numpy.ndarray' objects}
#    477356    0.206    0.000    0.206    0.000 {method 'take' of 'numpy.ndarray' objects}
#    477356    0.067    0.000    0.067    0.000 {method 'tolist' of 'numpy.ndarray' objects}
#    477368    0.038    0.000    0.038    0.000 {pandas._libs.algos.ensure_object}
#   3341492    0.243    0.000    0.243    0.000 {pandas._libs.algos.ensure_platform_int}
#    477356    1.088    0.000    1.088    0.000 {pandas._libs.algos.take_1d_int64_int64}
#         6    0.000    0.000    0.000    0.000 {pandas._libs.lib.array_equivalent_object}
#    954712    1.913    0.000    3.268    0.000 {pandas._libs.lib.infer_dtype}
#    477356    0.044    0.000    0.044    0.000 {pandas._libs.lib.is_bool_list}
#    954712    0.071    0.000    0.071    0.000 {pandas._libs.lib.is_bool}
#   1909424    0.131    0.000    0.131    0.000 {pandas._libs.lib.is_float}
#   2864136    0.201    0.000    0.201    0.000 {pandas._libs.lib.is_integer}
#   3341492    0.225    0.000    0.225    0.000 {pandas._libs.lib.is_iterator}
#   7637696    1.309    0.000    1.509    0.000 {pandas._libs.lib.is_list_like}
#   4773560    0.384    0.000    0.384    0.000 {pandas._libs.lib.is_scalar}
#   1909424    0.137    0.000    0.137    0.000 {pandas._libs.lib.item_from_zerodim}
#   1909424    5.167    0.000    9.066    0.000 {pandas._libs.lib.maybe_convert_objects}
